# %% [markdown]
# # Behavior Sequence Transformer (BST)
#
# **Alibaba**
#
# - **Description**: Combines the powerful sequence modeling of Transformers with the feature crossing ability of Wide & Deep. It takes user behavior sequences and other side information features as input.
# - **Use Case**: Ranking / CTR Prediction.
# - **Status**: Placeholder - To be implemented.

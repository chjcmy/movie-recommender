# %% [markdown]
# # LightGCN
#
# **SOTA Graph Neural Network**
#
# - **Description**: A simplified Graph Convolutional Network (GCN) for recommendation that linearly propagates user and item embeddings on the interaction graph. It captures high-order connectivity (A likes B, B likes C -> A might like C).
# - **Use Case**: Collaborative Filtering / Retrieval.
# - **Status**: Placeholder - To be implemented.
